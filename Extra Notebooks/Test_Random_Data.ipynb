# %% [markdown]
# #### <span style="color:red">**Predict Hazard from Asteroid JSON Values**</span>

# %%
import pandas as pd
import joblib
import requests
from pathlib import Path

# %% [markdown]
# <span style="color:blue">**Paste in your copied JSON below**</span>

# %%
# replace the JSON below with your coied JSON data after the '=' sign
json_data = {
    "Absolute_Magnitude": 25.82534,
    "Est_Dia_In_Km_Min": 1.04728,
    "Est_Dia_In_Km_Max": 2.47438,
    "Relative_Velocity_Km_Per_Hr": 42753.78344,
    "Miss_Dist_Kilometers": 36994457.44224,
    "Minimum_Orbit_Intersection": 0.33502,
    "Jupiter_Tisserand_Invariant": 2.78778,
    "Epoch_Osculation": 2456340.00466,
    "Eccentricity": 0.14951,
    "Semi_Major_Axis": 2.07651,
    "Inclination": 24.00582,
    "Asc_Node_Longitude": 175.11222,
    "Orbital_Period": 296.94879,
    "Perihelion_Distance": 1.23196,
    "Perihelion_Arg": 226.64071,
    "Aphelion_Dist": 1.66601,
    "Perihelion_Time": 2457404.51305,
    "Mean_Anomaly": 88.87916,
    "Mean_Motion": 1.57764,
    "Hazardous": 0
}

# %%
if json_data['Hazardous'] == 1:
    print("The asteroid is hazardous")
else:
    print("The asteroid is not hazardous")
# Out:
# The asteroid is not hazardous

# %% [markdown]
# <span style="color:red">**Prepare dataframe for prediction**</span>

# %%
df = pd.DataFrame([json_data]).drop(columns=['Hazardous'])
df
# Out:
#    Absolute_Magnitude  Est_Dia_In_Km_Min  Est_Dia_In_Km_Max  \
# 0            25.82534            1.04728            2.47438
#
#    Relative_Velocity_Km_Per_Hr  Miss_Dist_Kilometers  \
# 0                  42753.78344          3.699446e+07
#
#    Minimum_Orbit_Intersection  Jupiter_Tisserand_Invariant  Epoch_Osculation  \
# 0                     0.33502                      2.78778      2.456340e+06
#
#    Eccentricity  Semi_Major_Axis  Inclination  Asc_Node_Longitude  \
# 0       0.14951          2.07651     24.00582           175.11222
#
#    Orbital_Period  Perihelion_Distance  Perihelion_Arg  Aphelion_Dist  \
# 0       296.94879              1.23196       226.64071        1.66601
#
#    Perihelion_Time  Mean_Anomaly  Mean_Motion
# 0     2.457405e+06      88.87916      1.57764

# %% [markdown]
# <span style="color:red">**Load ML models**</span>

# %%
CWD = Path.cwd().parent
MODEL = CWD / 'Model'
HAZARD_MODEL_PATH = MODEL / 'hazard_model.pkl'
SCALER_PATH = MODEL / 'scaler.pkl'


hazard_model = joblib.load(HAZARD_MODEL_PATH)
scaler = joblib.load(SCALER_PATH)

# %% [markdown]
# <span style="color:red">**Transform data to fit model**</span>

# %%
df_scaled = scaler.transform(df)

# %% [markdown]
# <span style="color:red">**Prediction**</span>

# %%
prediction = hazard_model.predict(df_scaled)[0]
print("Prediction:", "Hazardous" if prediction == 1 else "Not Hazardous")
# Out:
# Prediction: Not Hazardous

# %% [markdown]
# <span style="color:red">**Prediction confidence**</span>

# %%
proba = hazard_model.predict_proba(df_scaled)[0][1]

print("Probability of being Safe:", 100-(round(proba * 100, 2)), "%")
print("Probability of being hazardous:", round(proba * 100, 2), "%")
# Out:
# Probability of being Safe: 93.0 %
# Probability of being hazardous: 7.0 %
